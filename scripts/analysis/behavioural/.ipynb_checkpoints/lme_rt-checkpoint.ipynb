# %% [markdown]
# # Linear mixed effects model on reaction times

# %% [markdown]
# Analysing reaction time measures from comprehension questions.

# %%
import sys
import os.path as op
import pandas as pd
import numpy as np

import statsmodels.api as sm
import statsmodels.formula.api as smf

import seaborn as sns
import matplotlib.pyplot as plt
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_style("white")

sys.path.append('/imaging/hauk/rl05/fake_diamond/scripts/preprocessing')
import config

logs_dir = config.logs_dir

subjects = config.subject_ids
print('Subjects:', subjects)
runs = [1,2,3,4,5]
# Out:
# Subjects: ['01', '02', '03', '04', '05', '06', '08', '09', '10', '11', '12', '13', '14', '15', '16', '17']

# %%
subjects_logs = []

for subject in subjects:
    
    subject = f'sub-{subject}'
    
    logs_fname = op.join(logs_dir, f'{subject}_logfile.csv')
    log_tmp = pd.read_csv(logs_fname)
    log_tmp = log_tmp.drop(columns='Unnamed: 10')
    
    subjects_logs.append(log_tmp)
    
data = pd.concat(subjects_logs)
del subjects_logs


# get conditions because i forgot to save them in logfiles :(
stimuli = pd.read_csv('/home/rl05/ownCloud/projects/fake_diamond/scripts/stimulus_presentation/stimuli_test.csv')
data.set_index('item_nr', inplace=True)
# data['answer'] = data.index.map(stimuli['answer'])
# data['condition'] = data.index.map(stimuli['condition_name'])
# data['experiment'] = data.index.map(stimuli['experiment'])
# data['experiment'] = data['experiment'].replace('concreteness_denotation','compose')
data.reset_index(inplace=True)

# log transform RT
data['LogRT'] = np.log(data['RT'])

# only keep correct responses
data = data[data.hit == 1.0] # only analysing reaction times from trials answered correctly

# calculate length of task questions
# data_compose['probe_length'] = data_compose['probe'].str.len() # number of letters
data['probe_length'] = data['probe'].str.split().apply(len) # number of words

# remove outliers


data
# Out:
#        item_nr  participant  block_nr  trial_nr  set_nr      word1    word2  \
# 2          745            1         1         3      49   htbqzylm    horse
# 16         895            1         1        17      99        xkq  weather
# 24         463            1         1        25      78       real  shotgun
# 45         698            1         1        46      33      guide      dog
# 54         367            1         1        55      62    typical  pudding
# ...        ...          ...       ...       ...     ...        ...      ...
# 14337      708           17         5       118      36  vpbyzkgrf     rose
# 14341      767           17         5       122      56  nocturnal   mammal
# 14347       70           17         5       128      12    typical  blunder
# 14374      465           17         5       155      78  vpbyzkgrf  shotgun
# 14399      189           17         5       180      32   kmlsdjtw   battle
#
#                                 probe response        RT  hit  \
# 2                Does it have scales?       Ry  1.903904  1.0
# 16                 Is it predictable?       Ry  1.475055  1.0
# 24     Is it to be handled with care?       Rb  2.479371  1.0
# 45                Is it disobedient?        Ry  1.699456  1.0
# 54                      Is it edible?       Rb  1.627648  1.0
# ...                               ...      ...       ...  ...
# 14337                 Is it fragrant?       Rb  2.585143  1.0
# 14341               Does it lay eggs?       Ry  2.266939  1.0
# 14347          Should it be repeated?       Ry  2.445462  1.0
# 14374                     Is it safe?       Ry  2.095398  1.0
# 14399                  Is it violent?       Rb  2.357696  1.0
#
#                  condition   experiment     LogRT  probe_length
# 2                      low  specificity  0.643907             4
# 16                     low  specificity  0.388695             3
# 24     concrete_subsective      compose  0.908005             7
# 45                     mid  specificity  0.530308             3
# 54     concrete_subsective      compose  0.487136             3
# ...                    ...          ...       ...           ...
# 14337                 high  specificity  0.949781             3
# 14341                  mid  specificity  0.818430             4
# 14347  abstract_subsective      compose  0.894234             4
# 14374    concrete_baseline      compose  0.739743             3
# 14399    concrete_baseline      compose  0.857685             3
#
# [1117 rows x 15 columns]

# %%
data.groupby(['participant'])['hit'].sum()/90*100
# Out:
# participant
# 1     64.444444
# 2     83.333333
# 3     65.555556
# 4     76.666667
# 5     78.888889
# 6     77.777778
# 8     80.000000
# 9     75.555556
# 10    84.444444
# 11    78.888889
# 12    81.111111
# 13    84.444444
# 14    81.111111
# 15    74.444444
# 16    82.222222
# 17    72.222222
# Name: hit, dtype: float64

# %%
data.groupby(['probe'])['hit'].sum()/84*100
# Out:
# probe
# Are they poor?                         4.761905
# Can it be from a story?               16.666667
# Can it be used as a prop on stage?    14.285714
# Can it be used in a battle?           10.714286
# Can you easily move it around?        11.904762
#                                         ...
# Is it violent?                        17.857143
# Is there disagreement?                13.095238
# Should it be neglected?               16.666667
# Should it be repeated?                15.476190
# Should it be taught in school?        11.904762
# Name: hit, Length: 84, dtype: float64

# %% [markdown]
# First look at reaction time data. We expect a positively skewed distribution.

# %%
# plt.Figure(figsize=(10,5))
axis = sns.kdeplot(data=data, x='RT', hue='answer', palette='PuOr')
sns.move_legend(axis, "upper left", bbox_to_anchor=(1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_29652/3428816463.py in <cell line: 2>()
#       1 # plt.Figure(figsize=(10,5))
# ----> 2 axis = sns.kdeplot(data=data, x='RT', hue='answer', palette='PuOr')
#       3 sns.move_legend(axis, "upper left", bbox_to_anchor=(1, 1))
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/distributions.py in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1736     # - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - #
#    1737
# -> 1738     p = _DistributionPlotter(
#    1739         data=data,
#    1740         variables=_DistributionPlotter.get_semantics(locals()),
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/distributions.py in __init__(self, data, variables)
#     109     ):
#     110
# --> 111         super().__init__(data=data, variables=variables)
#     112
#     113     @property
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/_core.py in __init__(self, data, variables)
#     603     def __init__(self, data=None, variables={}):
#     604
# --> 605         self.assign_variables(data, variables)
#     606
#     607         for var, cls in self._semantic_mappings.items():
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/_core.py in assign_variables(self, data, variables)
#     666         else:
#     667             self.input_format = "long"
# --> 668             plot_data, variables = self._assign_variables_longform(
#     669                 data, **variables,
#     670             )
#
# /imaging/local/software/miniconda/envs/mne1.0.3/lib/python3.10/site-packages/seaborn/_core.py in _assign_variables_longform(self, data, **kwargs)
#     901
#     902                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 903                 raise ValueError(err)
#     904
#     905             else:
#
# ValueError: Could not interpret value `answer` for parameter `hue`

# %% [markdown]
# Task questions in this study have variable lengths. That is, the number of words per question may differ across conditions. Let's look at the variance and see if it differs across conditions.

# %%
print('Number of total trials entering analysis:', len(data))
print(data[['word1','word2','probe','probe_length']].head(7))
# Out:
# Number of total trials entering analysis: 1117
#         word1    word2                           probe  probe_length
# 2    htbqzylm    horse            Does it have scales?             4
# 16        xkq  weather              Is it predictable?             3
# 24       real  shotgun  Is it to be handled with care?             7
# 45      guide      dog             Is it disobedient?              3
# 54    typical  pudding                   Is it edible?             3
# 59  vpbyzkgrf  shotgun                     Is it safe?             3
# 86    tqvgqrz    skill           Do musicians have it?             4

# %%
axis = sns.kdeplot(data=data, 
                   x='probe_length', 
                   hue='condition', 
                   fill=False, 
                   alpha=0.8, 
                   palette='PuOr')
sns.move_legend(axis, "upper left", bbox_to_anchor=(1, 1))

# %% [markdown]
# We deal with this by regressing question length (operationalised as number of letters in questions) out of reaction time data.

# %%
X = data['probe_length']  
X = sm.add_constant(X)  # add a constant term (intercept) to the model
y = data['LogRT'] # this 

model = sm.OLS(y, X).fit()

# get the residuals (regressed out RT)
data['LogRT_residual'] = model.resid
data[['probe_length','LogRT','LogRT_residual']].head(5)
# Out:
#     probe_length     LogRT  LogRT_residual
# 2              4  0.643907        0.299064
# 16             3  0.388695        0.092770
# 24             7  0.908005        0.416411
# 45             3  0.530308        0.234383
# 54             3  0.487136        0.191211

# %%
data.groupby('condition')[['LogRT','LogRT_residual']].describe()
# Out:
#                      LogRT                                                    \
#                      count      mean       std       min       25%       50%
# condition
# abstract_baseline    100.0  0.550203  0.284122 -0.177021  0.363848  0.577586
# abstract_privative   115.0  0.443777  0.312646 -0.340926  0.219272  0.474184
# abstract_subsective  121.0  0.350018  0.326402 -0.320125  0.115114  0.315785
# concrete_baseline     86.0  0.544281  0.290353 -0.042450  0.294959  0.541082
# concrete_privative   150.0  0.233970  0.311827 -0.357918 -0.015941  0.228834
# concrete_subsective  119.0  0.475484  0.290933 -0.193830  0.278740  0.503546
# high                 145.0  0.302822  0.323648 -0.647025  0.072437  0.305537
# low                  140.0  0.284876  0.300299 -0.389805  0.050395  0.283622
# mid                  141.0  0.274594  0.319959 -0.355069  0.041349  0.286261
#
#                                         LogRT_residual                      \
#                           75%       max          count      mean       std
# condition
# abstract_baseline    0.757663  1.084881          100.0  0.182370  0.288565
# abstract_privative   0.648594  1.017980          115.0  0.081920  0.306611
# abstract_subsective  0.607640  1.073695          121.0 -0.023124  0.317150
# concrete_baseline    0.745908  1.055121           86.0  0.112981  0.282382
# concrete_privative   0.463403  1.075738          150.0 -0.106632  0.305618
# concrete_subsective  0.698433  1.047451          119.0  0.051716  0.294478
# high                 0.533238  1.096942          145.0 -0.038309  0.331815
# low                  0.502338  0.949781          140.0 -0.068701  0.297157
# mid                  0.461693  1.071649          141.0 -0.067820  0.320625
#
#
#                           min       25%       50%       75%       max
# condition
# abstract_baseline   -0.570780 -0.005569  0.183827  0.427476  0.703873
# abstract_privative  -0.685768 -0.117006  0.120379  0.283788  0.673138
# abstract_subsective -0.711920 -0.242214 -0.052130  0.207491  0.631018
# concrete_baseline   -0.459863 -0.098171  0.140843  0.318832  0.698723
# concrete_privative  -0.849512 -0.344517 -0.125400  0.115011  0.779813
# concrete_subsective -0.611400 -0.136433  0.055938  0.251609  0.737433
# high                -0.942950 -0.280425 -0.042236  0.199451  0.752100
# low                 -0.685730 -0.285595 -0.066397  0.149868  0.653856
# mid                 -0.737037 -0.309253 -0.058581  0.135135  0.726807

# %% [markdown]
# # Composition

# %%
data_compose = data[data.experiment == 'compose'].copy()
data_compose[['concreteness', 'denotation']] = data_compose.loc[:,'condition'].str.split('_', n=1, expand=True)
data_compose.head(3)
# Out:
#     item_nr  participant  block_nr  trial_nr  set_nr      word1    word2  \
# 24      463            1         1        25      78       real  shotgun
# 54      367            1         1        55      62    typical  pudding
# 59      465            1         1        60      78  vpbyzkgrf  shotgun
#
#                              probe response        RT  hit  \
# 24  Is it to be handled with care?       Rb  2.479371  1.0
# 54                   Is it edible?       Rb  1.627648  1.0
# 59                     Is it safe?       Ry  1.676517  1.0
#
#               condition experiment     LogRT  probe_length  LogRT_residual  \
# 24   concrete_privative    compose  0.908005             7        0.416411
# 54   concrete_privative    compose  0.487136             3        0.191211
# 59  abstract_subsective    compose  0.516719             3        0.220794
#
#    concreteness  denotation
# 24     concrete   privative
# 54     concrete   privative
# 59     abstract  subsective

# %%
summary_stats = data_compose.groupby('concreteness')['RT'].agg(Mean='mean', SD='std').reset_index()
print(summary_stats)
# Out:
#   concreteness      Mean        SD
# 0     abstract  1.634411  0.509914
# 1     concrete  1.557734  0.508576

# %%
summary_stats = data_compose.groupby('denotation')['RT'].agg(Mean='mean', SD='std').reset_index()
print(summary_stats)
# Out:
#    denotation      Mean        SD
# 0    baseline  1.798529  0.495986
# 1   privative  1.460299  0.484680
# 2  subsective  1.586050  0.499457

# %% [markdown]
# Visualise distribution of reaction times by condition

# %%
np.array
# Out:
# <function numpy.array>

# %%
# hue_order = ['concrete_baseline','concrete_subsective','concrete_privative',
#              'abstract_baseline','abstract_subsective','abstract_privative',]
# colors = np.array([plt.cm.Oranges(np.linspace(0.3, 0.9, 3)),
#                   plt.cm.Blues(np.linspace(0.3, 0.9, 3))])
axis = sns.kdeplot(data=data_compose, x='LogRT_residual', hue='denotation', 
#                    hue_order=hue_order,
#                    color=colors,
                   fill=False, alpha=0.8, 
                   palette='PuOr'
                  )
sns.move_legend(axis, "upper left", bbox_to_anchor=(1, 1))

# %%
plt.figure(figsize=(8, 3))
hue_order = ['concrete_baseline','concrete_subsective','concrete_privative',
             'abstract_baseline','abstract_subsective','abstract_privative',]
axis = sns.kdeplot(data=data_compose, x='LogRT_residual', hue='condition', 
            hue_order=hue_order,
            fill=False, alpha=0.8, palette='PuOr')
sns.despine()
sns.move_legend(axis, "upper left", bbox_to_anchor=(1, 1))
plt.show()
