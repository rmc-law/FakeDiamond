# %% [markdown]
# # Make adjective-noun phrases

# %% [markdown]
# Now that we have a cleaned list of concrete and abstract words, we can work on constructing phrases.

# %%
import numpy as np
import pandas as pd
import re
import requests
import os
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date

dir = 'U:\ownCloud\projects\FakeDiamond\stimuli'

# %% [markdown]
# ## Adjectives

# %% [markdown]
# We are interested in studying whether the conceptual semantic system is sensitive to one kind of fine-grained distinction studied in linguistic semantics, called denotational semantics. Denotational semantics are driven by subsective adjectives (e.g., good, typical) and non-subsective adjectives (e.g., fake, former). The contrast in denotation arises only when the adjective composes with a noun. For example, a "typical diamond" is a diamond, while a "fake diamond" is not a diamond.

# %% [markdown]
# We start with non-subsective adjectives because they are more sparsely distributed in natural language. [Nayak and colleagues (2014)](https://www.cis.upenn.edu/~ccb/publications/non-subsective-adjectives.pdf) compiled a list of non-subsective adjectives. We focused on the privative kind, which has a list of 24 adjectives. We then removed adjectives for which we don't have readily available frequency measures (e.g., anti-, ex-, pseudosimulated, adjectives we think are archaic (e.g., erstwhile), and adjectives we think doesn't go well with our nouns (e.g., onetime, deputy). This results in the following 16 privative, non-subsective adjectives.

# %%
privatives = ['artificial','counterfeit','fabricated','fake','false',
              'fictional','fictitious','former','hypothetical','imaginary',
              'mock','mythical','past','phony','spurious','virtual']

# %% [markdown]
# Subsective adjectives are much easier to find. We started with a list of adjectives (n=300) compiled by Lalisse and Asudeh (2015). We then used their classification of subsectives to narrow down to the same number of non-subsective adjectives we obtained above (n=16) that we think would go well with a wide array of concrete and abstract nouns.

# %%
subsectives = ['actual','authentic','average','bad','current',
               'genuine','good','important','new','old',
               'perfect','real','special','true','typical','unique']

# %% [markdown]
# Implement Excel's VLOOKUP function to get a bunch of psycholinguistic properties of these adjectives:
# - Zipf frequency measures from SUBTLEX-UK
# - semantic diversity from Hoffman et al. (2012)
# - age of acquisition ratings from Kuperman et al. (2012)
# - concreteness ratings from Brysbaert et al. (2014)

# %%
adjectives = pd.DataFrame(data={'word':subsectives+privatives,'type':['subsective']*len(subsectives)+['privative']*len(privatives)})

# read in SUBTLEX UK data
subtlex = pd.read_csv(os.path.join(dir, 'resources', 'SUBTLEX-UK.csv'))
subtlex.rename(columns={'Spelling': 'word', 'LogFreq(Zipf)':'Zipf_frequency'}, inplace=True)
subtlex.set_index('word', inplace=True)
subtlex = subtlex[subtlex.index.notnull()]

# get zipf frequency for each adjective
adjectives['zipf_frequency'] = ''
adjectives.set_index('word', inplace=True)
adjectives['zipf_frequency'] = adjectives.index.map(subtlex['Zipf_frequency'])
adjectives.reset_index(inplace=True)

# read in semantic diversity data
semd = pd.read_csv(os.path.join(dir, 'resources', 'semantic_diversity_Hoffman_etal2012.csv'))
semd.set_index('item', inplace=True)
semd = semd[semd.index.notnull()]

# get semantic diversity for each adjective
adjectives['sem_d'] = ''
adjectives.set_index('word', inplace=True)
adjectives['sem_d'] = adjectives.index.map(semd['SemD'])
adjectives.reset_index(inplace=True)

# read in age of acquisition data
AoA = pd.read_csv(os.path.join(dir, 'resources', 'AoA_ratings_Kuperman_et_al_BRM.csv'))
AoA.set_index('Word', inplace=True)
AoA = AoA[AoA.index.notnull()]

# get semantic diversity for each adjective
adjectives['AoA'] = ''
adjectives.set_index('word', inplace=True)
adjectives['AoA'] = adjectives.index.map(AoA['Rating.Mean'])
adjectives.reset_index(inplace=True)

# read in age of acquisition data
concreteness = pd.read_csv(os.path.join(dir, 'resources', 'brysbaert_etal_2014.csv'))
concreteness.set_index('Word', inplace=True)
concreteness = concreteness[concreteness.index.notnull()]

# get semantic diversity for each adjective
adjectives['concreteness'] = ''
adjectives.set_index('word', inplace=True)
adjectives['concreteness'] = adjectives.index.map(concreteness['Conc_M'])
adjectives.reset_index(inplace=True)

# count word length in number of letters
adjectives['length'] = adjectives['word'].str.len()
adjectives
# Out:
# C:\Users\rl05\AppData\Local\Temp\ipykernel_16588\3866361078.py:4: DtypeWarning: Columns (11,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   subtlex = pd.read_csv(os.path.join(dir, 'resources', 'SUBTLEX-UK.csv'))
#             word        type  zipf_frequency  sem_d    AoA  concreteness  \
# 0         actual  subsective            4.60   2.10   6.94          2.22
# 1      authentic  subsective            3.73   1.76   8.42          2.31
# 2        average  subsective            4.73   1.96   8.90          2.40
# 3            bad  subsective            5.56   1.98   2.79          1.68
# 4        current  subsective            4.81   2.13   8.94          3.16
# 5        genuine  subsective            4.37   2.10   9.06          2.03
# 6           good  subsective            6.35   2.20   3.55          1.64
# 7      important  subsective            5.57   2.26   5.79          2.14
# ...

# %% [markdown]
# ### Visualising psycholinguistic properties of these adjectives

# %%
f, ax = plt.subplots(3, 2, figsize=(15,15))
sns.set_context(font_scale=2)
sns.histplot(x='zipf_frequency', hue='type', data=adjectives, ax=ax[0,0], element='step')
sns.histplot(x='AoA', hue='type', data=adjectives, ax=ax[1,0], element='step')
sns.histplot(x='concreteness', hue='type', data=adjectives, ax=ax[1,1], element='step')
sns.histplot(x='length', hue='type', data=adjectives, ax=ax[2,0], element='step')
sns.histplot(x='sem_d', hue='type', data=adjectives, ax=ax[2,1])
f.suptitle('Psycholinguistic properties of {} adjectives'.format(int(len(adjectives))), fontsize=16)
# Out:
# Text(0.5, 0.98, 'Psycholinguistic properties of 32 adjectives')

# %% [markdown]
# # Phrases
# Print out the adjectives together with some example nouns to see if they work well together.

# %%
# read in our cleaned list of nouns 
nouns = pd.read_csv(os.path.join(dir, 'nouns_cleaned_2023-03-01.csv'))

# put some phrases together just to get a sense
adjectives['concrete_example'] = adjectives['word'] + ' ' + nouns.query('condition == "concrete"')['word'].head(len(adjectives)).tolist()
adjectives['abstract_example'] = adjectives['word'] + ' ' + nouns.query('condition == "abstract"')['word'].head(len(adjectives)).tolist()
adjectives
# Out:
#             word        type  zipf_frequency  sem_d    AoA  concreteness  \
# 0         actual  subsective            4.60   2.10   6.94          2.22
# 1      authentic  subsective            3.73   1.76   8.42          2.31
# 2        average  subsective            4.73   1.96   8.90          2.40
# 3            bad  subsective            5.56   1.98   2.79          1.68
# 4        current  subsective            4.81   2.13   8.94          3.16
# 5        genuine  subsective            4.37   2.10   9.06          2.03
# 6           good  subsective            6.35   2.20   3.55          1.64
# 7      important  subsective            5.57   2.26   5.79          2.14
# 8            new  subsective            5.98   2.34   4.72          2.81
# 9            old  subsective            5.79   2.14   3.72          2.72
# 10       perfect  subsective            5.28   1.96   5.78          1.69
# 11          real  subsective            5.53   2.17   4.95          2.50
# ...

# %% [markdown]
# Fully cross the adjectives (n=32) and nouns (n=844) to make phrases

# %%
# repeat each noun n times, where n is the number of adjectives we have
phrases = pd.DataFrame(np.repeat(nouns[['set','word','condition']].values, len(adjectives), axis=0), columns=['set','noun','concreteness'])

# repeat each adjective n times, where n is the number of nouns we have
phrases['adjective'] = adjectives.word.tolist()*len(nouns)

# annotate each adjective with its denotation (e.g., subsective or privative)
phrases['denotation'] = np.repeat(['subsective','privative'], len(adjectives)/2).tolist()*len(nouns)

# compose phrases
phrases['phrase'] = phrases['adjective'] + ' ' + phrases['noun']
phrases
# Out:
#        set     noun concreteness  adjective  denotation             phrase
# 0        1  costume     concrete     actual  subsective     actual costume
# 1        1  costume     concrete  authentic  subsective  authentic costume
# 2        1  costume     concrete    average  subsective    average costume
# 3        1  costume     concrete        bad  subsective        bad costume
# 4        1  costume     concrete    current  subsective    current costume
# ...    ...      ...          ...        ...         ...                ...
# 27003  422   moment     abstract   mythical   privative    mythical moment
# 27004  422   moment     abstract       past   privative        past moment
# 27005  422   moment     abstract      phony   privative       phony moment
# 27006  422   moment     abstract   spurious   privative    spurious moment
# 27007  422   moment     abstract    virtual   privative     virtual moment
#
# [27008 rows x 6 columns]

# %% [markdown]
# ## Calculate phrase frequency

# %% [markdown]
# Calculate two types of bigram frequencies in the past 100 years (1919-2019) in British English
# - average bigram frequency
# - average frequency of dependency between target adjective and noun--adjective modifying the noun conceptually, not just in bigrams (e.g., tasty frozen pizza, tasty pizza)

# %%
# first split phrase dataframe into four chunks for looping
phrases_blocks = np.array_split(phrases, 4)

# parameters for Google Books Ngram
corpus = 'eng-GB-2019' # British English
startYear, endYear = 1919, 2019 # most recent 100 years available on Google Books Ngram
smoothing = 3 # for extrapolating in case there's missing; this is default setting 
caseInsensitive = True 

for blockNum, phrases_block in enumerate(phrases_blocks):
    print(f'Calculating bigram frequency, block {blockNum+1}')
    frequencies_dep = [] # dependency frequency
    frequencies_seq = [] # sequence frequency
    frequencies_all = [frequencies_dep, frequencies_seq] # for looping
    for index, row in phrases_block.iterrows():
        query_w2w1 = row.noun + '_NOUN' + '=>' + row.adjective + '_ADJ' # dependency frequency
        query_w1w2 = row.adjective + '_ADJ' + ' ' + row.noun + '_NOUN' # sequence frequency
        queries = [query_w2w1, query_w1w2] # for looping

        for query, frequencies in zip(queries, frequencies_all):
            params = dict(content=query, year_start=startYear, year_end=endYear,
                          corpus=corpus, smoothing=smoothing,
                          case_insensitive=caseInsensitive)
            req = requests.get('http://books.google.com/ngrams/graph', params=params)
            res = re.findall('"timeseries": \[(.*?)\]}', req.text) # find timeseries associated with each query
            if res: 
                timeseries = list(map(float, res[0].split(','))) 
                average_frequency = sum(timeseries) / len(timeseries) # calculate mean frequency across time
                frequencies.append(average_frequency)
            else: 
                frequencies.append(0)
    phrases_block['frequency_dep'] = frequencies_dep
    phrases_block['frequency_seq'] = frequencies_seq
    phrases_block.to_csv(os.path.join(f'phrases_block{blockNum+1}_{date.today()}.csv'), index=False)
    print(f'Block {blockNum+1} done.')
# Out:
# Calculating bigram frequency, block 1
# Block 1 done.
# Calculating bigram frequency, block 2
# Block 2 done.
# Calculating bigram frequency, block 3
# Block 3 done.
# Calculating bigram frequency, block 4
# Block 4 done.

# %% [markdown]
# ## Visualise bigram frequency distribution

# %%
# put back the phrase blocks into one big df
blocks = []
for i in range(len(phrases_blocks)):
    blocks.append(pd.read_csv(os.path.join(f'phrases_block{i+1}_2023-03-01.csv')))
phrases = pd.concat(blocks)
phrases.reset_index(inplace=True, drop=True)

# calculate log frequencies 
phrases['frequency_dep_log'] = np.log10(phrases['frequency_dep'])
phrases['frequency_seq_log'] = np.log10(phrases['frequency_seq'])

# define sethood as phrases sharing a noun
phrases['set'] = np.repeat(list(map(lambda x:x+1, list(range(int(len(nouns)))))), 32)  # add set number for future use
col = phrases.pop('set') 
phrases.insert(0, col.name, col) # move set to the front of df

phrases
# Out:
# C:\Users\rl05\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\rl05\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#        set     noun concreteness  adjective  denotation             phrase  \
# 0        1  costume     concrete     actual  subsective     actual costume
# 1        1  costume     concrete  authentic  subsective  authentic costume
# 2        1  costume     concrete    average  subsective    average costume
# 3        1  costume     concrete        bad  subsective        bad costume
# 4        1  costume     concrete    current  subsective    current costume
# ...    ...      ...          ...        ...         ...                ...
# 27003  844   moment     abstract   mythical   privative    mythical moment
# ...

# %% [markdown]
# Find the best phrase in each set of phrases. That is, the phrase with the highest bigram frequency.

# %%
for denotation in ['subsective','privative']:
    print(denotation)
# Out:
# subsective
# privative

# %%
phrases_best_indices = []
for i in range(1, len(nouns)+1):    
    # find phrase with highest frequency in each denotation
    for j in ['subsective','privative']:
        phrase_set = phrases.query(f'(set=={i}) and (denotation=="{j}")')
        phrase_best = phrase_set[phrase_set.frequency_dep == phrase_set.frequency_dep.max()] 
        phrases_best_indices.append(phrase_best.index[0])
phrases.iloc[phrases_best_indices]
# Out:
#        set     noun concreteness     adjective  denotation  \
# 8        1  costume     concrete           new  subsective
# 23       1  costume     concrete        former   privative
# 42       2  crystal     concrete       perfect  subsective
# 56       2  crystal     concrete  hypothetical   privative
# 64       3    pedal     concrete        actual  subsective
# ...    ...      ...          ...           ...         ...
# 26928  842  decorum     abstract    artificial   privative
# 26944  843      way     abstract        actual  subsective
# 26960  843      way     abstract    artificial   privative
# 26976  844   moment     abstract        actual  subsective
# 26992  844   moment     abstract    artificial   privative
#
#                      phrase  frequency_dep  frequency_seq  frequency_dep_log  \
# 8               new costume   1.704543e-08   1.450543e-08          -7.768392
# 23           former costume   3.450579e-10   3.291223e-10          -9.462108
# ...

# %%
best_phrases.query('frequency_dep > 0').phrase.tolist()
# Out:
# ['new costume',
#  'former costume',
#  'perfect crystal',
#  'hypothetical crystal',
#  'past perfume',
#  'new trophy',
#  'imaginary trophy',
#  'new record',
#  'past record',
#  'actual door',
#  'spurious flour',
#  'old stone',
#  'artificial stone',
#  'old snorer',
#  'good lager',
#  'good pint',
#  'former pint',
#  'new mesh',
#  'virtual mesh',
#  'good cricket',
#  'typical archway',
#  'former archway',
#  'good mulch',
#  'artificial mulch',
#  'new serum',
#  'artificial serum',
#  'former nylon',
#  'new limo',
#  'new toolkit',
#  'artificial toolkit',
#  'new cap',
#  'former cap',
#  'new belt',
#  'artificial belt',
#  'good cognac',
#  'true onyx',
#  'artificial onyx',
#  'real venom',
#  'former venom',
#  'new wheel',
#  'past stubble',
#  'bad gash',
#  'new speck',
#  'imaginary speck',
#  'virtual brain',
#  'good cigar',
#  'imaginary cigar',
#  'new pyramid',
#  'imaginary pyramid',
#  'mock growl',
#  'new video',
#  'virtual video',
#  'old puss',
# ...

# %%
best_phrases = phrases.iloc[phrases_best_indices]
print(best_phrases.query('frequency_dep > 0').groupby(['concreteness','denotation']).size())

# f, ax = plt.subplots(1, 2, figsize=(15,3))
# sns.histplot(x='frequency_dep_log', hue='denotation', data=best_phrases.query('frequency_dep == 0'), ax=ax[0], element='step').set(title='Log-transformed bigram frequency based on dependency')
# Out:
# concreteness  denotation
# abstract      privative     47
#               subsective    51
# concrete      privative     38
#               subsective    45
# dtype: int64

# %% [markdown]
# The log frequency distributions of both phrase types (subsective and non-subsective) after removing zero frequencies:

# %%
f, ax = plt.subplots(1, 2, figsize=(15,3))
sns.set_context(font_scale=2)
sns.histplot(x='frequency_dep_log', hue='denotation', data=phrases, ax=ax[0], element='step').set(title='Log-transformed bigram frequency based on dependency')
sns.histplot(x='frequency_seq_log', hue='denotation', data=phrases, ax=ax[1], element='step').set(title='Log-transformed bigram frequency based on sequence')
# Out:
# [Text(0.5, 1.0, 'Log-transformed bigram frequency based on sequence')]

# %%
f, ax = plt.subplots(1, 2, figsize=(15,3))
sns.set_context(font_scale=2)
sns.histplot(x='frequency_dep', hue='denotation', data=phrases.query('frequency_dep > 0'), ax=ax[0], element='step').set(title='bigram frequency based on dependency')
sns.histplot(x='frequency_seq', hue='denotation', data=phrases.query('frequency_seq > 0'), ax=ax[1], element='step').set(title='bigram frequency based on sequence')
# Out:
# [Text(0.5, 1.0, 'bigram frequency based on sequence')]

# %% [markdown]
# Number of phrases by concreteness conditions after removing zero frequencies

# %%
phrases.query('frequency_dep > 0 & frequency_seq > 0')['noun'].nunique()
# Out:
# 112

# %% [markdown]
# Looking at how the removal of zero bigram frequencies impact our psycholinguistic property matching:

# %%
nouns_long
# Out:
#         word  item_nr condition      Zipf   PoS  Length    AoA  CNC_M  CNC_SD
# 0    costume        4  concrete  4.171842  noun       7   4.17   4.57    0.86
# 1    crystal        9  concrete  4.162752  noun       7   7.78   4.58    0.81
# 2      pedal       11  concrete  3.634756  noun       5   6.50   4.44    0.97
# 3       rook       13  concrete  2.888860  noun       4  11.59   4.38    1.10
# 4       mink       14  concrete  3.128705  noun       4  10.32   4.58    0.99
# ..       ...      ...       ...       ...   ...     ...    ...    ...     ...
# 839  anarchy     2548  abstract  3.155128  noun       7  13.94   2.12    1.31
# 840     jilt     2568  abstract  1.598826  noun       4  12.28   2.00    1.15
# 841  decorum     2572  abstract  2.767618  noun       7  15.12   2.36    1.50
# 842      way     2582  abstract  6.118429  noun       3   5.39   2.34    1.37
# 843   moment     2625  abstract  5.574384  noun       6   7.95   1.61    1.10
#
# [844 rows x 9 columns]

# %%
phrases_nonzero = phrases.query('frequency_dep > 0 & frequency_seq > 0').reset_index()

# read in cleaned noun list to get psycholinguistic properties
nouns_long = pd.read_csv(os.path.join(dir, 'nouns_cleaned_2023-03-01.csv'), index_col=False)
nouns_long.set_index('word', inplace=True)

phrases_nonzero['noun_zipf'] = ''
phrases_nonzero['noun_aoa'] = ''
phrases_nonzero['noun_length'] = ''
phrases_nonzero['noun_cnc'] = ''
phrases_nonzero.set_index('noun', inplace=True)
phrases_nonzero['noun_zipf'] = phrases_nonzero.index.map(nouns_long['Zipf'])
phrases_nonzero['noun_aoa'] = phrases_nonzero.index.map(nouns_long['AoA'])
phrases_nonzero['noun_length'] = phrases_nonzero.index.map(nouns_long['Length'])
phrases_nonzero['noun_cnc'] = phrases_nonzero.index.map(nouns_long['CNC_M'])

phrases_nonzero.reset_index(inplace=True)
phrases_nonzero
# Out:
#          noun  index concreteness  adjective  denotation             phrase  \
# 0     costume      0     concrete     actual  subsective     actual costume
# 1     costume      1     concrete  authentic  subsective  authentic costume
# 2     costume      2     concrete    average  subsective    average costume
# 3     costume      3     concrete        bad  subsective        bad costume
# 4     costume      4     concrete    current  subsective    current costume
# ...       ...    ...          ...        ...         ...                ...
# 1519   rehash  26822     abstract       good  subsective        good rehash
# 1520   rehash  26824     abstract        new  subsective         new rehash
# 1521   rehash  26825     abstract        old  subsective         old rehash
# 1522   rehash  26847     abstract    virtual   privative     virtual rehash
# 1523  anarchy  26848     abstract     actual  subsective     actual anarchy
#
# ...

# %%
f, ax = plt.subplots(2, 2, figsize=(15,15))
sns.set_context(font_scale=2)
sns.histplot(x='noun_cnc', hue='concreteness', data=phrases_nonzero, ax=ax[0,0], element='step').set(title='Concreteness mean')
# sns.scatterplot(x='Conc_M', y='Conc_SD', data=ratings_all, s=2, alpha=0.5, ax=ax[0,1], color='black').set(title='Concreteness mean-SD distribution')
# sns.scatterplot(x='noun_cnc', y='CNC_SD', data=phrases_nonzero.query('condition == "abstract"'), s=5, alpha=0.7, ax=ax[0,1], color=(0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# )
# sns.scatterplot(x='noun_cnc', y='CNC_SD', data=phrases_nonzero.query('condition == "concrete"'), s=5, alpha=1, ax=ax[0,1], color=(1.0, 0.4980392156862745, 0.054901960784313725)
# )
sns.histplot(x='noun_aoa', hue='concreteness', data=phrases_nonzero, ax=ax[0,1], element='step').set(title='Age of acquisition')
sns.histplot(x='noun_zipf', hue='concreteness', data=phrases_nonzero, ax=ax[1,0], element='step').set(title='Zipf frequency')
sns.histplot(x='noun_length', hue='concreteness', data=phrases_nonzero, ax=ax[1,1], element='step').set(title='Word length')
# f.suptitle('Psycholinguistic properties of {} concrete-abstract word pairs'.format(int(len(nouns_long)/2)), fontsize=16)
# Out:
# [Text(0.5, 1.0, 'Word length')]

# %% [markdown]
# ## Calculate transition probability

# %%
from nltk.corpus.reader.bnc import BNCCorpusReader
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder

# %%
bnc_reader = BNCCorpusReader(root='U:\BNC\download\Texts', fileids=r'[A-K]/\w*/\w*\.xml')
finder_backup = BigramCollocationFinder.from_words(bnc_reader.words(fileids=None))

# %%
finder = finder_backup

# Ngrams with target as a member
creature_filter = lambda *w: 'diamond' not in w

## Bigrams
finder = BigramCollocationFinder.from_words(bnc_reader.words(fileids=None))
# only bigrams that appear 3+ times
finder.apply_freq_filter(3)
# only bigrams that contain 'creature'
finder.apply_ngram_filter(creature_filter)
# return the 10 n-grams with the highest PMI
print (finder.nbest(bigram_measures.likelihood_ratio, 10))
# Out:
# [('diamond', 'ring'), ('a', 'diamond'), ('diamond', 'sapphire'), ('diamond', 'jubilee'), ('diamond', 'cluster'), ('little', 'diamond'), ('rough', 'diamond'), ('diamond', 'solitaire'), ('µm', 'diamond'), ('diamond', 'rings')]

# %%
finder

# %%
finder = finder_backup
creature_filter = lambda *w: 'diamond' not in w
finder_backup.apply_ngram_filter(creature_filter)
print (finder.nbest(bigram_measures.likelihood_ratio, 10))
# Out:
# []
