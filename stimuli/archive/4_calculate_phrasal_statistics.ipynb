# %% [markdown]
# # Calculate phrasal statistics

# %% [markdown]
# Check that our phrases don't differ across conditions in terms of statistical properties, such as bigram frequency in corpora or transition probability.

# %%
import numpy as np
import pandas as pd
import re
import requests
import os
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
import random

dir = 'U:\ownCloud\projects\FakeDiamond\stimuli'

# %% [markdown]
# # Phrases

# %%
adjectives_subsective = ['actual','authentic','average','bad','current','genuine','good','important',
                         'new','old','perfect','real','special','true','typical','unique']
#                          'standard','rare','classic','permanent','temporary','famous','regular','simple']
adjectives_privative = ['artificial','counterfeit','fabricated','fake','false','fictional','fictitious','former',
                        'hypothetical','imaginary','mock','mythical','past','phony','spurious','virtual'] 
consonant_strings = ['xkq', 'qxsw', 'mtpv', 'rjdnw', 'wvcnz', 'zbxlv','tqvgqrz', 'bxfjwts','mghljkqr',
                     'kmlsdjtw','ptrgsbkv','zrtqgfplh','vpbyzkgrf','htbqzylm','ypdcglkc','fxldmr','rvqf']

# %%
# read in our cleaned list of nouns 
nouns = pd.read_csv(os.path.join(dir, 'nouns_cleaned_2023-04-14.csv'))

# shuffle adjectives, then repeat them into a list of 298 adjectives
def create_adjective_list(adjectives, nouns):
    adjectives_repeated = (adjectives * 19)[:len(nouns)]
    adjectives_repeated_shuffled = random.Random(42).sample(adjectives_repeated, len(adjectives_repeated)) # create random.Random instance for reproducibility
    return adjectives_repeated_shuffled

array_adjectives = np.empty((3, len(nouns)), dtype='object') # initialise array
for i, adjectives in enumerate([adjectives_subsective,adjectives_privative,consonant_strings]):
    array_adjectives[i] = create_adjective_list(adjectives, nouns)
    
# transpose and flatten to put into big df later
adjectives_all = np.transpose(array_adjectives).flatten()

phrases = pd.DataFrame(np.repeat(nouns.values, 3, axis=0)) # repeat critical nouns 3 times for 3 denotation conditions
phrases.columns = nouns.columns # assign column names 
phrases['denotation'] = ['subsective','privative','baseline'] * len(nouns) # add denotation condition

phrases['adjective'] = adjectives_all
phrases.rename(columns={'item_nr': 'set_nr', 'word': 'noun'}, inplace=True)
phrases['phrase'] = nouns_x.adjective + ' ' + nouns_x.noun
phrases
# Out:
#         noun set_nr concreteness      Zipf Length Syllables Phonemes AoA  \
# 0    sulphur      1     concrete  3.351834      7         2        5   6
# 1    sulphur      1     concrete  3.351834      7         2        5   6
# 2    sulphur      1     concrete  3.351834      7         2        5   6
# 3    longing      1     abstract  3.408385      7         2        5   8
# 4    longing      1     abstract  3.408385      7         2        5   8
# ..       ...    ...          ...       ...    ...       ...      ...  ..
# 835  syringe    140     concrete  3.122247      7         2        5  10
# 836  syringe    140     concrete  3.122247      7         2        5  10
# 837    wrath    140     abstract  3.409226      5         1        3  12
# 838    wrath    140     abstract  3.409226      5         1        3  12
# 839    wrath    140     abstract  3.409226      5         1        3  12
#
#     CNC_M Valence          RT CNC_SD   IMAG  denotation  adjective  \
# 0    4.23  4.7647      668.25   1.25  4.727  subsective        old
# 1    4.23  4.7647      668.25   1.25  4.727   privative  imaginary
# 2    4.23  4.7647      668.25   1.25  4.727    baseline    tqvgqrz
# 3    2.14   4.303  679.666667   1.13  3.235  subsective    special
# 4    2.14   4.303  679.666667   1.13  3.235   privative       past
# ..    ...     ...         ...    ...    ...         ...        ...
# 835  4.81  3.4375  675.194444   0.57    6.4   privative  fictional
# 836  4.81  3.4375  675.194444   0.57    6.4    baseline      zbxlv
# 837  2.42  2.6364  627.324324   1.33  2.875  subsective       real
# 838  2.42  2.6364  627.324324   1.33  2.875   privative   mythical
# 839  2.42  2.6364  627.324324   1.33  2.875    baseline       rvqf
#
#                 phrase
# 0          old sulphur
# 1    imaginary sulphur
# 2      tqvgqrz sulphur
# 3      special longing
# 4         past longing
# ..                 ...
# 835  fictional syringe
# 836      zbxlv syringe
# 837         real wrath
# 838     mythical wrath
# 839         rvqf wrath
#
# [840 rows x 16 columns]

# %% [markdown]
# ## Calculate phrase frequency

# %% [markdown]
# Calculate two types of bigram frequencies in the past 100 years (1919-2019) in British English
# - average bigram frequency
# - average frequency of dependency between target adjective and noun--adjective modifying the noun conceptually, not just in bigrams (e.g., tasty frozen pizza, tasty pizza)

# %%
# parameters for Google Books Ngram
corpus = 'eng-GB-2019' # British English
startYear, endYear = 1919, 2019 # most recent 100 years available on Google Books Ngram
smoothing = 3 # for extrapolating in case there's missing; this is default setting 
caseInsensitive = True 

print(f'Calculating bigram frequency...')
frequencies_dep = [] # dependency frequency
frequencies_seq = [] # sequence frequency
frequencies_all = [frequencies_dep, frequencies_seq] # for looping
for index, row in phrases.iterrows():
    query_w2w1 = row.noun + '_NOUN' + '=>' + row.adjective + '_ADJ' # dependency frequency
    query_w1w2 = row.adjective + '_ADJ' + ' ' + row.noun + '_NOUN' # sequence frequency
    queries = [query_w2w1, query_w1w2] # for looping

    for query, frequencies in zip(queries, frequencies_all):
        params = dict(content=query, year_start=startYear, year_end=endYear,
                      corpus=corpus, smoothing=smoothing,
                      case_insensitive=caseInsensitive)
        req = requests.get('http://books.google.com/ngrams/graph', params=params)
        res = re.findall('"timeseries": \[(.*?)\]}', req.text) # find timeseries associated with each query
        if res: 
            timeseries = list(map(float, res[0].split(','))) 
            average_frequency = sum(timeseries) / len(timeseries) # calculate mean frequency across time
            frequencies.append(average_frequency)
        else: 
            frequencies.append(0)
    print(str(index+1) + ' out of ' + str(len(phrases)) + ' done.')
phrases['frequency_dep'] = frequencies_dep
phrases['frequency_seq'] = frequencies_seq
phrases.to_csv(os.path.join(f'phrases_bigramFreq_{date.today()}.csv'), index=False)
print()
# Out:
# Calculating bigram frequency...
# 1 out of 840 done.
# 2 out of 840 done.
# 3 out of 840 done.
# 4 out of 840 done.
# 5 out of 840 done.
# 6 out of 840 done.
# 7 out of 840 done.
# 8 out of 840 done.
# 9 out of 840 done.
# 10 out of 840 done.
# 11 out of 840 done.
# 12 out of 840 done.
# 13 out of 840 done.
# 14 out of 840 done.
# 15 out of 840 done.
# 16 out of 840 done.
# 17 out of 840 done.
# 18 out of 840 done.
# 19 out of 840 done.
# 20 out of 840 done.
# 21 out of 840 done.
# 22 out of 840 done.
# 23 out of 840 done.
# 24 out of 840 done.
# 25 out of 840 done.
# 26 out of 840 done.
# 27 out of 840 done.
# 28 out of 840 done.
# 29 out of 840 done.
# 30 out of 840 done.
# 31 out of 840 done.
# 32 out of 840 done.
# 33 out of 840 done.
# 34 out of 840 done.
# 35 out of 840 done.
# 36 out of 840 done.
# 37 out of 840 done.
# 38 out of 840 done.
# 39 out of 840 done.
# 40 out of 840 done.
# 41 out of 840 done.
# 42 out of 840 done.
# 43 out of 840 done.
# 44 out of 840 done.
# 45 out of 840 done.
# 46 out of 840 done.
# 47 out of 840 done.
# 48 out of 840 done.
# 49 out of 840 done.
# 50 out of 840 done.
# 51 out of 840 done.
# 52 out of 840 done.
# 53 out of 840 done.
# 54 out of 840 done.
# 55 out of 840 done.
# 56 out of 840 done.
# 57 out of 840 done.
# 58 out of 840 done.
# 59 out of 840 done.
# 60 out of 840 done.
# 61 out of 840 done.
# 62 out of 840 done.
# 63 out of 840 done.
# 64 out of 840 done.
# 65 out of 840 done.
# 66 out of 840 done.
# 67 out of 840 done.
# 68 out of 840 done.
# 69 out of 840 done.
# 70 out of 840 done.
# 71 out of 840 done.
# 72 out of 840 done.
# 73 out of 840 done.
# 74 out of 840 done.
# 75 out of 840 done.
# 76 out of 840 done.
# 77 out of 840 done.
# 78 out of 840 done.
# 79 out of 840 done.
# 80 out of 840 done.
# 81 out of 840 done.
# 82 out of 840 done.
# 83 out of 840 done.
# 84 out of 840 done.
# 85 out of 840 done.
# 86 out of 840 done.
# 87 out of 840 done.
# 88 out of 840 done.
# 89 out of 840 done.
# 90 out of 840 done.
# 91 out of 840 done.
# 92 out of 840 done.
# 93 out of 840 done.
# 94 out of 840 done.
# 95 out of 840 done.
# 96 out of 840 done.
# 97 out of 840 done.
# 98 out of 840 done.
# 99 out of 840 done.
# 100 out of 840 done.
# 101 out of 840 done.
# 102 out of 840 done.
# 103 out of 840 done.
# 104 out of 840 done.
# 105 out of 840 done.
# 106 out of 840 done.
# 107 out of 840 done.
# 108 out of 840 done.
# 109 out of 840 done.
# 110 out of 840 done.
# 111 out of 840 done.
# 112 out of 840 done.
# 113 out of 840 done.
# 114 out of 840 done.
# 115 out of 840 done.
# 116 out of 840 done.
# 117 out of 840 done.
# 118 out of 840 done.
# 119 out of 840 done.
# 120 out of 840 done.
# 121 out of 840 done.
# 122 out of 840 done.
# 123 out of 840 done.
# 124 out of 840 done.
# 125 out of 840 done.
# 126 out of 840 done.
# 127 out of 840 done.
# 128 out of 840 done.
# 129 out of 840 done.
# 130 out of 840 done.
# 131 out of 840 done.
# 132 out of 840 done.
# 133 out of 840 done.
# 134 out of 840 done.
# 135 out of 840 done.
# 136 out of 840 done.
# 137 out of 840 done.
# 138 out of 840 done.
# 139 out of 840 done.
# 140 out of 840 done.
# 141 out of 840 done.
# 142 out of 840 done.
# 143 out of 840 done.
# 144 out of 840 done.
# 145 out of 840 done.
# 146 out of 840 done.
# 147 out of 840 done.
# 148 out of 840 done.
# 149 out of 840 done.
# 150 out of 840 done.
# 151 out of 840 done.
# 152 out of 840 done.
# 153 out of 840 done.
# 154 out of 840 done.
# 155 out of 840 done.
# 156 out of 840 done.
# 157 out of 840 done.
# 158 out of 840 done.
# 159 out of 840 done.
# 160 out of 840 done.
# 161 out of 840 done.
# 162 out of 840 done.
# 163 out of 840 done.
# 164 out of 840 done.
# 165 out of 840 done.
# 166 out of 840 done.
# 167 out of 840 done.
# 168 out of 840 done.
# 169 out of 840 done.
# 170 out of 840 done.
# 171 out of 840 done.
# 172 out of 840 done.
# 173 out of 840 done.
# 174 out of 840 done.
# 175 out of 840 done.
# 176 out of 840 done.
# 177 out of 840 done.
# 178 out of 840 done.
# 179 out of 840 done.
# 180 out of 840 done.
# 181 out of 840 done.
# 182 out of 840 done.
# 183 out of 840 done.
# 184 out of 840 done.
# 185 out of 840 done.
# 186 out of 840 done.
# 187 out of 840 done.
# 188 out of 840 done.
# 189 out of 840 done.
# 190 out of 840 done.
# 191 out of 840 done.
# 192 out of 840 done.
# 193 out of 840 done.
# 194 out of 840 done.
# 195 out of 840 done.
# 196 out of 840 done.
# 197 out of 840 done.
# 198 out of 840 done.
# 199 out of 840 done.
# 200 out of 840 done.
# 201 out of 840 done.
# 202 out of 840 done.
# 203 out of 840 done.
# 204 out of 840 done.
# 205 out of 840 done.
# 206 out of 840 done.
# 207 out of 840 done.
# 208 out of 840 done.
# 209 out of 840 done.
# 210 out of 840 done.
# 211 out of 840 done.
# 212 out of 840 done.
# 213 out of 840 done.
# 214 out of 840 done.
# 215 out of 840 done.
# 216 out of 840 done.
# 217 out of 840 done.
# 218 out of 840 done.
# 219 out of 840 done.
# 220 out of 840 done.
# 221 out of 840 done.
# 222 out of 840 done.
# 223 out of 840 done.
# 224 out of 840 done.
# 225 out of 840 done.
# 226 out of 840 done.
# 227 out of 840 done.
# 228 out of 840 done.
# 229 out of 840 done.
# 230 out of 840 done.
# 231 out of 840 done.
# 232 out of 840 done.
# 233 out of 840 done.
# 234 out of 840 done.
# 235 out of 840 done.
# 236 out of 840 done.
# 237 out of 840 done.
# 238 out of 840 done.
# 239 out of 840 done.
# 240 out of 840 done.
# 241 out of 840 done.
# 242 out of 840 done.
# 243 out of 840 done.
# 244 out of 840 done.
# 245 out of 840 done.
# 246 out of 840 done.
# 247 out of 840 done.
# 248 out of 840 done.
# 249 out of 840 done.
# 250 out of 840 done.
# 251 out of 840 done.
# 252 out of 840 done.
# 253 out of 840 done.
# 254 out of 840 done.
# 255 out of 840 done.
# 256 out of 840 done.
# 257 out of 840 done.
# 258 out of 840 done.
# 259 out of 840 done.
# 260 out of 840 done.
# 261 out of 840 done.
# 262 out of 840 done.
# 263 out of 840 done.
# 264 out of 840 done.
# 265 out of 840 done.
# 266 out of 840 done.
# 267 out of 840 done.
# 268 out of 840 done.
# 269 out of 840 done.
# 270 out of 840 done.
# 271 out of 840 done.
# 272 out of 840 done.
# 273 out of 840 done.
# 274 out of 840 done.
# 275 out of 840 done.
# 276 out of 840 done.
# 277 out of 840 done.
# 278 out of 840 done.
# 279 out of 840 done.
# 280 out of 840 done.
# 281 out of 840 done.
# 282 out of 840 done.
# 283 out of 840 done.
# 284 out of 840 done.
# 285 out of 840 done.
# 286 out of 840 done.
# 287 out of 840 done.
# 288 out of 840 done.
# 289 out of 840 done.
# 290 out of 840 done.
# 291 out of 840 done.
# 292 out of 840 done.
# 293 out of 840 done.
# 294 out of 840 done.
# 295 out of 840 done.
# 296 out of 840 done.
# 297 out of 840 done.
# 298 out of 840 done.
# 299 out of 840 done.
# 300 out of 840 done.
# 301 out of 840 done.
# 302 out of 840 done.
# 303 out of 840 done.
# 304 out of 840 done.
# 305 out of 840 done.
# 306 out of 840 done.
# 307 out of 840 done.
# 308 out of 840 done.
# 309 out of 840 done.
# 310 out of 840 done.
# 311 out of 840 done.
# 312 out of 840 done.
# 313 out of 840 done.
# 314 out of 840 done.
# 315 out of 840 done.
# 316 out of 840 done.
# 317 out of 840 done.
# 318 out of 840 done.
# 319 out of 840 done.
# 320 out of 840 done.
# 321 out of 840 done.
# 322 out of 840 done.
# 323 out of 840 done.
# 324 out of 840 done.
# 325 out of 840 done.
# 326 out of 840 done.
# 327 out of 840 done.
# 328 out of 840 done.
# 329 out of 840 done.
# 330 out of 840 done.
# 331 out of 840 done.
# 332 out of 840 done.
# 333 out of 840 done.
# 334 out of 840 done.
# 335 out of 840 done.
# 336 out of 840 done.
# 337 out of 840 done.
# 338 out of 840 done.
# 339 out of 840 done.
# 340 out of 840 done.
# 341 out of 840 done.
# 342 out of 840 done.
# 343 out of 840 done.
# 344 out of 840 done.
# 345 out of 840 done.
# 346 out of 840 done.
# 347 out of 840 done.
# 348 out of 840 done.
# 349 out of 840 done.
# 350 out of 840 done.
# 351 out of 840 done.
# 352 out of 840 done.
# 353 out of 840 done.
# 354 out of 840 done.
# 355 out of 840 done.
# 356 out of 840 done.
# 357 out of 840 done.
# 358 out of 840 done.
# 359 out of 840 done.
# 360 out of 840 done.
# 361 out of 840 done.
# 362 out of 840 done.
# 363 out of 840 done.
# 364 out of 840 done.
# 365 out of 840 done.
# 366 out of 840 done.
# 367 out of 840 done.
# 368 out of 840 done.
# 369 out of 840 done.
# 370 out of 840 done.
# 371 out of 840 done.
# 372 out of 840 done.
# 373 out of 840 done.
# 374 out of 840 done.
# 375 out of 840 done.
# 376 out of 840 done.
# 377 out of 840 done.
# 378 out of 840 done.
# 379 out of 840 done.
# 380 out of 840 done.
# 381 out of 840 done.
# 382 out of 840 done.
# 383 out of 840 done.
# 384 out of 840 done.
# 385 out of 840 done.
# 386 out of 840 done.
# 387 out of 840 done.
# 388 out of 840 done.
# 389 out of 840 done.
# 390 out of 840 done.
# 391 out of 840 done.
# 392 out of 840 done.
# 393 out of 840 done.
# 394 out of 840 done.
# 395 out of 840 done.
# 396 out of 840 done.
# 397 out of 840 done.
# 398 out of 840 done.
# 399 out of 840 done.
# 400 out of 840 done.
# 401 out of 840 done.
# 402 out of 840 done.
# 403 out of 840 done.
# 404 out of 840 done.
# 405 out of 840 done.
# 406 out of 840 done.
# 407 out of 840 done.
# 408 out of 840 done.
# 409 out of 840 done.
# 410 out of 840 done.
# 411 out of 840 done.
# 412 out of 840 done.
# 413 out of 840 done.
# 414 out of 840 done.
# 415 out of 840 done.
# 416 out of 840 done.
# 417 out of 840 done.
# 418 out of 840 done.
# 419 out of 840 done.
# 420 out of 840 done.
# 421 out of 840 done.
# 422 out of 840 done.
# 423 out of 840 done.
# 424 out of 840 done.
# 425 out of 840 done.
# 426 out of 840 done.
# 427 out of 840 done.
# 428 out of 840 done.
# 429 out of 840 done.
# 430 out of 840 done.
# 431 out of 840 done.
# 432 out of 840 done.
# 433 out of 840 done.
# 434 out of 840 done.
# 435 out of 840 done.
# 436 out of 840 done.
# 437 out of 840 done.
# 438 out of 840 done.
# 439 out of 840 done.
# 440 out of 840 done.
# 441 out of 840 done.
# 442 out of 840 done.
# 443 out of 840 done.
# 444 out of 840 done.
# 445 out of 840 done.
# 446 out of 840 done.
# 447 out of 840 done.
# 448 out of 840 done.
# 449 out of 840 done.
# 450 out of 840 done.
# 451 out of 840 done.
# 452 out of 840 done.
# 453 out of 840 done.
# 454 out of 840 done.
# 455 out of 840 done.
# 456 out of 840 done.
# 457 out of 840 done.
# 458 out of 840 done.
# 459 out of 840 done.
# 460 out of 840 done.
# 461 out of 840 done.
# 462 out of 840 done.
# 463 out of 840 done.
# 464 out of 840 done.
# 465 out of 840 done.
# 466 out of 840 done.
# 467 out of 840 done.
# 468 out of 840 done.
# 469 out of 840 done.
# 470 out of 840 done.
# 471 out of 840 done.
# 472 out of 840 done.
# 473 out of 840 done.
# 474 out of 840 done.
# 475 out of 840 done.
# 476 out of 840 done.
# 477 out of 840 done.
# 478 out of 840 done.
# 479 out of 840 done.
# 480 out of 840 done.
# 481 out of 840 done.
# 482 out of 840 done.
# 483 out of 840 done.
# 484 out of 840 done.
# 485 out of 840 done.
# 486 out of 840 done.
# 487 out of 840 done.
# 488 out of 840 done.
# 489 out of 840 done.
# 490 out of 840 done.
# 491 out of 840 done.
# 492 out of 840 done.
# 493 out of 840 done.
# 494 out of 840 done.
# 495 out of 840 done.
# 496 out of 840 done.
# 497 out of 840 done.
# 498 out of 840 done.
# 499 out of 840 done.
# 500 out of 840 done.
# 501 out of 840 done.
# 502 out of 840 done.
# 503 out of 840 done.
# 504 out of 840 done.
# 505 out of 840 done.
# 506 out of 840 done.
# 507 out of 840 done.
# 508 out of 840 done.
# 509 out of 840 done.
# 510 out of 840 done.
# 511 out of 840 done.
# 512 out of 840 done.
# 513 out of 840 done.
# 514 out of 840 done.
# 515 out of 840 done.
# 516 out of 840 done.
# 517 out of 840 done.
# 518 out of 840 done.
# 519 out of 840 done.
# 520 out of 840 done.
# 521 out of 840 done.
# 522 out of 840 done.
# 523 out of 840 done.
# 524 out of 840 done.
# 525 out of 840 done.
# 526 out of 840 done.
# 527 out of 840 done.
# 528 out of 840 done.
# 529 out of 840 done.
# 530 out of 840 done.
# 531 out of 840 done.
# 532 out of 840 done.
# 533 out of 840 done.
# 534 out of 840 done.
# 535 out of 840 done.
# 536 out of 840 done.
# 537 out of 840 done.
# 538 out of 840 done.
# 539 out of 840 done.
# 540 out of 840 done.
# 541 out of 840 done.
# 542 out of 840 done.
# 543 out of 840 done.
# 544 out of 840 done.
# 545 out of 840 done.
# 546 out of 840 done.
# 547 out of 840 done.
# 548 out of 840 done.
# 549 out of 840 done.
# 550 out of 840 done.
# 551 out of 840 done.
# 552 out of 840 done.
# 553 out of 840 done.
# 554 out of 840 done.
# 555 out of 840 done.
# 556 out of 840 done.
# 557 out of 840 done.
# 558 out of 840 done.
# 559 out of 840 done.
# 560 out of 840 done.
# 561 out of 840 done.
# 562 out of 840 done.
# 563 out of 840 done.
# 564 out of 840 done.
# 565 out of 840 done.
# 566 out of 840 done.
# 567 out of 840 done.
# 568 out of 840 done.
# 569 out of 840 done.
# 570 out of 840 done.
# 571 out of 840 done.
# 572 out of 840 done.
# 573 out of 840 done.
# 574 out of 840 done.
# 575 out of 840 done.
# 576 out of 840 done.
# 577 out of 840 done.
# 578 out of 840 done.
# 579 out of 840 done.
# 580 out of 840 done.
# 581 out of 840 done.
# 582 out of 840 done.
# 583 out of 840 done.
# 584 out of 840 done.
# 585 out of 840 done.
# 586 out of 840 done.
# 587 out of 840 done.
# 588 out of 840 done.
# 589 out of 840 done.
# 590 out of 840 done.
# 591 out of 840 done.
# 592 out of 840 done.
# 593 out of 840 done.
# 594 out of 840 done.
# 595 out of 840 done.
# 596 out of 840 done.
# 597 out of 840 done.
# 598 out of 840 done.
# 599 out of 840 done.
# 600 out of 840 done.
# 601 out of 840 done.
# 602 out of 840 done.
# 603 out of 840 done.
# 604 out of 840 done.
# 605 out of 840 done.
# 606 out of 840 done.
# 607 out of 840 done.
# 608 out of 840 done.
# 609 out of 840 done.
# 610 out of 840 done.
# 611 out of 840 done.
# 612 out of 840 done.
# 613 out of 840 done.
# 614 out of 840 done.
# 615 out of 840 done.
# 616 out of 840 done.
# 617 out of 840 done.
# 618 out of 840 done.
# 619 out of 840 done.
# 620 out of 840 done.
# 621 out of 840 done.
# 622 out of 840 done.
# 623 out of 840 done.
# 624 out of 840 done.
# 625 out of 840 done.
# 626 out of 840 done.
# 627 out of 840 done.
# 628 out of 840 done.
# 629 out of 840 done.
# 630 out of 840 done.
# 631 out of 840 done.
# 632 out of 840 done.
# 633 out of 840 done.
# 634 out of 840 done.
# 635 out of 840 done.
# 636 out of 840 done.
# 637 out of 840 done.
# 638 out of 840 done.
# 639 out of 840 done.
# 640 out of 840 done.
# 641 out of 840 done.
# 642 out of 840 done.
# 643 out of 840 done.
# 644 out of 840 done.
# 645 out of 840 done.
# 646 out of 840 done.
# 647 out of 840 done.
# 648 out of 840 done.
# 649 out of 840 done.
# 650 out of 840 done.
# 651 out of 840 done.
# 652 out of 840 done.
# 653 out of 840 done.
# 654 out of 840 done.
# 655 out of 840 done.
# 656 out of 840 done.
# 657 out of 840 done.
# 658 out of 840 done.
# 659 out of 840 done.
# 660 out of 840 done.
# 661 out of 840 done.
# 662 out of 840 done.
# 663 out of 840 done.
# 664 out of 840 done.
# 665 out of 840 done.
# 666 out of 840 done.
# 667 out of 840 done.
# 668 out of 840 done.
# 669 out of 840 done.
# 670 out of 840 done.
# 671 out of 840 done.
# 672 out of 840 done.
# 673 out of 840 done.
# 674 out of 840 done.
# 675 out of 840 done.
# 676 out of 840 done.
# 677 out of 840 done.
# 678 out of 840 done.
# 679 out of 840 done.
# 680 out of 840 done.
# 681 out of 840 done.
# 682 out of 840 done.
# 683 out of 840 done.
# 684 out of 840 done.
# 685 out of 840 done.
# 686 out of 840 done.
# 687 out of 840 done.
# 688 out of 840 done.
# 689 out of 840 done.
# 690 out of 840 done.
# 691 out of 840 done.
# 692 out of 840 done.
# 693 out of 840 done.
# 694 out of 840 done.
# 695 out of 840 done.
# 696 out of 840 done.
# 697 out of 840 done.
# 698 out of 840 done.
# 699 out of 840 done.
# 700 out of 840 done.
# 701 out of 840 done.
# 702 out of 840 done.
# 703 out of 840 done.
# 704 out of 840 done.
# 705 out of 840 done.
# 706 out of 840 done.
# 707 out of 840 done.
# 708 out of 840 done.
# 709 out of 840 done.
# 710 out of 840 done.
# 711 out of 840 done.
# 712 out of 840 done.
# 713 out of 840 done.
# 714 out of 840 done.
# 715 out of 840 done.
# 716 out of 840 done.
# 717 out of 840 done.
# 718 out of 840 done.
# 719 out of 840 done.
# 720 out of 840 done.
# 721 out of 840 done.
# 722 out of 840 done.
# 723 out of 840 done.
# 724 out of 840 done.
# 725 out of 840 done.
# 726 out of 840 done.
# 727 out of 840 done.
# 728 out of 840 done.
# 729 out of 840 done.
# 730 out of 840 done.
# 731 out of 840 done.
# 732 out of 840 done.
# 733 out of 840 done.
# 734 out of 840 done.
# 735 out of 840 done.
# 736 out of 840 done.
# 737 out of 840 done.
# 738 out of 840 done.
# 739 out of 840 done.
# 740 out of 840 done.
# 741 out of 840 done.
# 742 out of 840 done.
# 743 out of 840 done.
# 744 out of 840 done.
# 745 out of 840 done.
# 746 out of 840 done.
# 747 out of 840 done.
# 748 out of 840 done.
# 749 out of 840 done.
# 750 out of 840 done.
# 751 out of 840 done.
# 752 out of 840 done.
# 753 out of 840 done.
# 754 out of 840 done.
# 755 out of 840 done.
# 756 out of 840 done.
# 757 out of 840 done.
# 758 out of 840 done.
# 759 out of 840 done.
# 760 out of 840 done.
# 761 out of 840 done.
# 762 out of 840 done.
# 763 out of 840 done.
# 764 out of 840 done.
# 765 out of 840 done.
# 766 out of 840 done.
# 767 out of 840 done.
# 768 out of 840 done.
# 769 out of 840 done.
# 770 out of 840 done.
# 771 out of 840 done.
# 772 out of 840 done.
# 773 out of 840 done.
# 774 out of 840 done.
# 775 out of 840 done.
# 776 out of 840 done.
# 777 out of 840 done.
# 778 out of 840 done.
# 779 out of 840 done.
# 780 out of 840 done.
# 781 out of 840 done.
# 782 out of 840 done.
# 783 out of 840 done.
# 784 out of 840 done.
# 785 out of 840 done.
# 786 out of 840 done.
# 787 out of 840 done.
# 788 out of 840 done.
# 789 out of 840 done.
# 790 out of 840 done.
# 791 out of 840 done.
# 792 out of 840 done.
# 793 out of 840 done.
# 794 out of 840 done.
# 795 out of 840 done.
# 796 out of 840 done.
# 797 out of 840 done.
# 798 out of 840 done.
# 799 out of 840 done.
# 800 out of 840 done.
# 801 out of 840 done.
# 802 out of 840 done.
# 803 out of 840 done.
# 804 out of 840 done.
# 805 out of 840 done.
# 806 out of 840 done.
# 807 out of 840 done.
# 808 out of 840 done.
# 809 out of 840 done.
# 810 out of 840 done.
# 811 out of 840 done.
# 812 out of 840 done.
# 813 out of 840 done.
# 814 out of 840 done.
# 815 out of 840 done.
# 816 out of 840 done.
# 817 out of 840 done.
# 818 out of 840 done.
# 819 out of 840 done.
# 820 out of 840 done.
# 821 out of 840 done.
# 822 out of 840 done.
# 823 out of 840 done.
# 824 out of 840 done.
# 825 out of 840 done.
# 826 out of 840 done.
# 827 out of 840 done.
# 828 out of 840 done.
# 829 out of 840 done.
# 830 out of 840 done.
# 831 out of 840 done.
# 832 out of 840 done.
# 833 out of 840 done.
# 834 out of 840 done.
# 835 out of 840 done.
# 836 out of 840 done.
# 837 out of 840 done.
# 838 out of 840 done.
# 839 out of 840 done.
# 840 out of 840 done.

# %% [markdown]
# ## Visualise bigram frequency distribution

# %%
# # put back the phrase blocks into one big df
# blocks = []
# for i in range(len(phrases_blocks)):
#     blocks.append(pd.read_csv(os.path.join(f'phrases_block{i+1}_2023-03-01.csv')))
# phrases = pd.concat(blocks)
# phrases.reset_index(inplace=True, drop=True)

# calculate log frequencies 
phrases['frequency_dep_log'] = np.log10(phrases['frequency_dep'])
phrases['frequency_seq_log'] = np.log10(phrases['frequency_seq'])

# # define sethood as phrases sharing a noun
# phrases['set'] = np.repeat(list(map(lambda x:x+1, list(range(int(len(nouns)))))), 32)  # add set number for future use
# col = phrases.pop('set') 
# phrases.insert(0, col.name, col) # move set to the front of df

phrases
# Out:
# C:\Users\rl05\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\Users\rl05\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         noun set_nr concreteness      Zipf Length Syllables Phonemes AoA  \
# 0    sulphur      1     concrete  3.351834      7         2        5   6
# 1    sulphur      1     concrete  3.351834      7         2        5   6
# 2    sulphur      1     concrete  3.351834      7         2        5   6
# 3    longing      1     abstract  3.408385      7         2        5   8
# 4    longing      1     abstract  3.408385      7         2        5   8
# ..       ...    ...          ...       ...    ...       ...      ...  ..
# 835  syringe    140     concrete  3.122247      7         2        5  10
# 836  syringe    140     concrete  3.122247      7         2        5  10
# 837    wrath    140     abstract  3.409226      5         1        3  12
# 838    wrath    140     abstract  3.409226      5         1        3  12
# 839    wrath    140     abstract  3.409226      5         1        3  12
#
#     CNC_M Valence          RT CNC_SD   IMAG  denotation  adjective  \
# 0    4.23  4.7647      668.25   1.25  4.727  subsective        old
# 1    4.23  4.7647      668.25   1.25  4.727   privative  imaginary
# 2    4.23  4.7647      668.25   1.25  4.727    baseline    tqvgqrz
# 3    2.14   4.303  679.666667   1.13  3.235  subsective    special
# 4    2.14   4.303  679.666667   1.13  3.235   privative       past
# ..    ...     ...         ...    ...    ...         ...        ...
# 835  4.81  3.4375  675.194444   0.57    6.4   privative  fictional
# 836  4.81  3.4375  675.194444   0.57    6.4    baseline      zbxlv
# 837  2.42  2.6364  627.324324   1.33  2.875  subsective       real
# 838  2.42  2.6364  627.324324   1.33  2.875   privative   mythical
# 839  2.42  2.6364  627.324324   1.33  2.875    baseline       rvqf
#
#                 phrase  frequency_dep  frequency_seq  frequency_dep_log  \
# 0          old sulphur   5.791099e-10   1.709172e-09          -9.237239
# 1    imaginary sulphur   0.000000e+00   0.000000e+00               -inf
# 2      tqvgqrz sulphur   0.000000e+00   0.000000e+00               -inf
# 3      special longing   6.415080e-10   5.920740e-10          -9.192798
# 4         past longing   2.164082e-10   1.657856e-10          -9.664726
# ..                 ...            ...            ...                ...
# 835  fictional syringe   0.000000e+00   0.000000e+00               -inf
# 836      zbxlv syringe   0.000000e+00   0.000000e+00               -inf
# 837         real wrath   0.000000e+00   0.000000e+00               -inf
# 838     mythical wrath   0.000000e+00   0.000000e+00               -inf
# 839         rvqf wrath   0.000000e+00   0.000000e+00               -inf
#
#      frequency_seq_log
# 0            -8.767214
# 1                 -inf
# 2                 -inf
# 3            -9.227624
# 4            -9.780453
# ..                 ...
# 835               -inf
# 836               -inf
# 837               -inf
# 838               -inf
# 839               -inf
#
# [840 rows x 20 columns]

# %% [markdown]
# Find the best phrase in each set of phrases. That is, the phrase with the highest bigram frequency.

# %%
# phrases_best_indices = []
# for i in range(1, len(nouns)+1):    
#     # find phrase with highest frequency in each denotation
#     for j in ['subsective','privative']:
#         phrase_set = phrases.query(f'(set=={i}) and (denotation=="{j}")')
#         phrase_best = phrase_set[phrase_set.frequency_dep == phrase_set.frequency_dep.max()] 
#         phrases_best_indices.append(phrase_best.index[0])
# phrases.iloc[phrases_best_indices]

# %%
# best_phrases.query('frequency_dep > 0').phrase.tolist()

# %%
best_phrases = phrases.iloc[phrases_best_indices]
print(best_phrases.query('frequency_dep > 0').groupby(['concreteness','denotation']).size())

# f, ax = plt.subplots(1, 2, figsize=(15,3))
# sns.histplot(x='frequency_dep_log', hue='denotation', data=best_phrases.query('frequency_dep == 0'), ax=ax[0], element='step').set(title='Log-transformed bigram frequency based on dependency')

# %% [markdown]
# The log frequency distributions of both phrase types (subsective and non-subsective) after removing zero frequencies:

# %%
fig, axes = plt.subplots(1,2, figsize=(11,2))
sns.set_context(font_scale=2)
sns.set_theme(style='white', palette='Set1')
sns.histplot(x='frequency_dep_log', hue='denotation', data=phrases, ax=axes[0], element='bars').set(title='Log-transformed bigram frequency based on dependency')
sns.histplot(x='frequency_seq_log', hue='denotation', data=phrases, ax=axes[1], element='bars').set(title='Log-transformed bigram frequency based on sequence')
# Out:
# [Text(0.5, 1.0, 'Log-transformed bigram frequency based on sequence')]

# %%
f, ax = plt.subplots(1, 2, figsize=(11,2))
sns.set_context(font_scale=2)
sns.set_theme(style='white', palette='Set1')
sns.histplot(x='frequency_dep', hue='denotation', data=phrases.query('frequency_dep > 0'), ax=ax[0], element='step').set(title='bigram frequency based on dependency')
sns.histplot(x='frequency_seq', hue='denotation', data=phrases.query('frequency_seq > 0'), ax=ax[1], element='step').set(title='bigram frequency based on sequence')
# Out:
# [Text(0.5, 1.0, 'bigram frequency based on sequence')]

# %% [markdown]
# Number of phrases by concreteness conditions after removing zero frequencies

# %%
phrases.query('frequency_dep > 0 & frequency_seq > 0')['noun'].nunique()
# Out:
# 112

# %% [markdown]
# Looking at how the removal of zero bigram frequencies impact our psycholinguistic property matching:

# %%
nouns_long
# Out:
#         word  item_nr condition      Zipf   PoS  Length    AoA  CNC_M  CNC_SD
# 0    costume        4  concrete  4.171842  noun       7   4.17   4.57    0.86
# 1    crystal        9  concrete  4.162752  noun       7   7.78   4.58    0.81
# 2      pedal       11  concrete  3.634756  noun       5   6.50   4.44    0.97
# 3       rook       13  concrete  2.888860  noun       4  11.59   4.38    1.10
# 4       mink       14  concrete  3.128705  noun       4  10.32   4.58    0.99
# ..       ...      ...       ...       ...   ...     ...    ...    ...     ...
# 839  anarchy     2548  abstract  3.155128  noun       7  13.94   2.12    1.31
# 840     jilt     2568  abstract  1.598826  noun       4  12.28   2.00    1.15
# 841  decorum     2572  abstract  2.767618  noun       7  15.12   2.36    1.50
# 842      way     2582  abstract  6.118429  noun       3   5.39   2.34    1.37
# 843   moment     2625  abstract  5.574384  noun       6   7.95   1.61    1.10
#
# [844 rows x 9 columns]

# %%
phrases_nonzero = phrases.query('frequency_dep > 0 & frequency_seq > 0').reset_index()

# read in cleaned noun list to get psycholinguistic properties
nouns_long = pd.read_csv(os.path.join(dir, 'nouns_cleaned_2023-03-01.csv'), index_col=False)
nouns_long.set_index('word', inplace=True)

phrases_nonzero['noun_zipf'] = ''
phrases_nonzero['noun_aoa'] = ''
phrases_nonzero['noun_length'] = ''
phrases_nonzero['noun_cnc'] = ''
phrases_nonzero.set_index('noun', inplace=True)
phrases_nonzero['noun_zipf'] = phrases_nonzero.index.map(nouns_long['Zipf'])
phrases_nonzero['noun_aoa'] = phrases_nonzero.index.map(nouns_long['AoA'])
phrases_nonzero['noun_length'] = phrases_nonzero.index.map(nouns_long['Length'])
phrases_nonzero['noun_cnc'] = phrases_nonzero.index.map(nouns_long['CNC_M'])

phrases_nonzero.reset_index(inplace=True)
phrases_nonzero
# Out:
#          noun  index concreteness  adjective  denotation             phrase  \
# 0     costume      0     concrete     actual  subsective     actual costume
# 1     costume      1     concrete  authentic  subsective  authentic costume
# 2     costume      2     concrete    average  subsective    average costume
# 3     costume      3     concrete        bad  subsective        bad costume
# 4     costume      4     concrete    current  subsective    current costume
# ...       ...    ...          ...        ...         ...                ...
# 1519   rehash  26822     abstract       good  subsective        good rehash
# 1520   rehash  26824     abstract        new  subsective         new rehash
# 1521   rehash  26825     abstract        old  subsective         old rehash
# 1522   rehash  26847     abstract    virtual   privative     virtual rehash
# 1523  anarchy  26848     abstract     actual  subsective     actual anarchy
#
#       frequency_dep  frequency_seq  frequency_dep_log  frequency_seq_log  \
# 0      1.196396e-09   1.114929e-09          -8.922125          -8.952753
# 1      3.224809e-09   1.961011e-09          -8.491496          -8.707520
# 2      1.823691e-10   1.800532e-10          -9.739049          -9.744599
# 3      2.735950e-10   2.411877e-10          -9.562892          -9.617645
# 4      3.180741e-10   2.764691e-10          -9.497472          -9.558353
# ...             ...            ...                ...                ...
# 1519   5.973443e-11   2.507194e-11         -10.223775         -10.600812
# 1520   6.649890e-11   3.511690e-11         -10.177186         -10.454484
# 1521   2.290375e-10   1.674349e-10          -9.640093          -9.776154
# 1522   2.312194e-11   1.991051e-11         -10.635976         -10.700918
# 1523   6.427935e-10   5.583275e-10          -9.191928          -9.253111
#
#       noun_zipf  noun_aoa  noun_length  noun_cnc
# 0      4.171842      4.17            7      4.57
# 1      4.171842      4.17            7      4.57
# 2      4.171842      4.17            7      4.57
# 3      4.171842      4.17            7      4.57
# 4      4.171842      4.17            7      4.57
# ...         ...       ...          ...       ...
# 1519   1.974489     12.24            6      2.17
# 1520   1.974489     12.24            6      2.17
# 1521   1.974489     12.24            6      2.17
# 1522   1.974489     12.24            6      2.17
# 1523   3.155128     13.94            7      2.12
#
# [1524 rows x 14 columns]

# %%
f, ax = plt.subplots(2, 2, figsize=(15,15))
sns.set_context(font_scale=2)
sns.histplot(x='noun_cnc', hue='concreteness', data=phrases_nonzero, ax=ax[0,0], element='step').set(title='Concreteness mean')
# sns.scatterplot(x='Conc_M', y='Conc_SD', data=ratings_all, s=2, alpha=0.5, ax=ax[0,1], color='black').set(title='Concreteness mean-SD distribution')
# sns.scatterplot(x='noun_cnc', y='CNC_SD', data=phrases_nonzero.query('condition == "abstract"'), s=5, alpha=0.7, ax=ax[0,1], color=(0.12156862745098039, 0.4666666666666667, 0.7058823529411765)
# )
# sns.scatterplot(x='noun_cnc', y='CNC_SD', data=phrases_nonzero.query('condition == "concrete"'), s=5, alpha=1, ax=ax[0,1], color=(1.0, 0.4980392156862745, 0.054901960784313725)
# )
sns.histplot(x='noun_aoa', hue='concreteness', data=phrases_nonzero, ax=ax[0,1], element='step').set(title='Age of acquisition')
sns.histplot(x='noun_zipf', hue='concreteness', data=phrases_nonzero, ax=ax[1,0], element='step').set(title='Zipf frequency')
sns.histplot(x='noun_length', hue='concreteness', data=phrases_nonzero, ax=ax[1,1], element='step').set(title='Word length')
# f.suptitle('Psycholinguistic properties of {} concrete-abstract word pairs'.format(int(len(nouns_long)/2)), fontsize=16)
# Out:
# [Text(0.5, 1.0, 'Word length')]

# %% [markdown]
# ## Calculate transition probability

# %%
from nltk.corpus.reader.bnc import BNCCorpusReader
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder

# %%
bnc_reader = BNCCorpusReader(root='U:\BNC\download\Texts', fileids=r'[A-K]/\w*/\w*\.xml')

# %%
from nltk.corpus import brown
finder = BigramCollocationFinder.from_words(brown.words())
bigram_measures = nltk.collocations.BigramAssocMeasures()

# %%
finder.apply_freq_filter(3)

# %%
creature_filter = lambda *w: 'diamond' not in w
finder.apply_ngram_filter(creature_filter)
# return the 10 n-grams with the highest PMI
bigram_measures = nltk.collocations.BigramAssocMeasures()
print (finder.nbest(bigram_measures.likelihood_ratio, 10))
# Out:
# []

# %%
bnc_reader = BNCCorpusReader(root='U:\BNC\download\Texts', fileids=r'[A-K]/\w*/\w*\.xml')
finder_backup = BigramCollocationFinder.from_words(bnc_reader.words(fileids=None))

# %%
finder = finder_backup

# Ngrams with target as a member
creature_filter = lambda *w: 'diamond' not in w

## Bigrams
finder = BigramCollocationFinder.from_words(bnc_reader.words(fileids=None))
# only bigrams that appear 3+ times
finder.apply_freq_filter(3)
# only bigrams that contain 'creature'
finder.apply_ngram_filter(creature_filter)
# return the 10 n-grams with the highest PMI
print (finder.nbest(bigram_measures.likelihood_ratio, 10))
# Out:
# [('diamond', 'ring'), ('a', 'diamond'), ('diamond', 'sapphire'), ('diamond', 'jubilee'), ('diamond', 'cluster'), ('little', 'diamond'), ('rough', 'diamond'), ('diamond', 'solitaire'), ('µm', 'diamond'), ('diamond', 'rings')]

# %%
finder

# %%
finder = finder_backup
creature_filter = lambda *w: 'diamond' not in w
finder_backup.apply_ngram_filter(creature_filter)
print (finder.nbest(bigram_measures.likelihood_ratio, 10))
# Out:
# []
